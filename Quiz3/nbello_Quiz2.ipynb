# %% [markdown]
# This was created modifiying quizzes frrm the **[MLDS (Machine Learning and data Science)](https://ingenieria.bogota.unal.edu.co/uec/?p=10947)** Training Program from "Unidad de Educación Continuada y Permanente" of the "Facultad de Ingeniería" at UNAL
#
# <img src = "https://i.ytimg.com/vi/S6xbNyvVyiY/maxresdefault.jpg" alt = "MLDS Header" width = "70%">  </img>
#
#
# <a href="https://youtu.be/S6xbNyvVyiY"><img src="https://ingenieria.bogota.unal.edu.co/uec/wp-content/uploads/2019/03/msedge_TiMVdqwZhD.png"
# alt="MLDS video" width = "70%"></a>

# %% [markdown]
# The MDLS Training Program has a **[free online Python course](https://ingenieria.bogota.unal.edu.co/uec/?p=14706)**.
#
# <img src = "https://ingenieria.bogota.unal.edu.co/uec/wp-content/uploads/2021/11/mooc_python.png" alt = "Encabezado MLDS" width = "70%">  </img>

# %% [markdown]
# # **Quiz 2 - *Titanic* - Python Pandas**
# ---
# This quiz will help you practice the skills coding in Python and using Numpy and Pandas.
#
# > **Note:** This aquiz will be graded on **UNCode** **[https://uncode.unal.edu.co/](https://uncode.unal.edu.co/)** ([doumentation](https://juezun.github.io/)). In each exercise is indicated where you should write your code. Complete the code, download the file submit it in **UNCode**.

# %%
# Importar pandas
import pandas as pd

# %%
#TEST_CELL
# !python --version
print('Pandas', pd.__version__)
# Out:
# Python 3.9.16
# Pandas 1.3.5

# %% [markdown]
# Este material fue realizado con las siguientes versiones:
#
# - *Python* 3.6.9
#
# - *Pandas* 1.1.5

# %% [markdown]
# ## **0. Read data file**

# %% [markdown]
# In this execise you practice the skills acquired using *pandas* in the process of exploring and understanding data sets. We will use the **Titanic dataset**  available from  **Kaggle** [https://www.kaggle.com/c/titanic](https://www.kaggle.com/c/titanic).
#
# The Titanic data set features multiple variables from the tragedy:
#
# ### Data Dictionary
#
# | Variable | Definition | Values |
# | --- | --- | --- |
# | survival | Survival | 0 = No, 1 = Yes |
# | pclass | Ticket class | 1 = 1st, 2 = 2nd, 3 = 3rd
# | sex | Sex | |
# | Age | Age in years | |
# | sibsp | # of siblings/spouse aboard Titanic | |
# | patch | # of parents / children aboard the Titanic | |
# | tickets | Ticket number | |
# | fare | Ticket cost | |
# | cabin | Cabin number | |
# | embarked | Port of embarkation | C=Cherbourg, Q=Queenstown, S=Southampton |
#
#
# > **IMPORTANT:**
#
#   - Please download the dataset file from the following link: **[titanic.csv](https://raw.githubusercontent.com/JuezUN/datasets/master/titanic.csv)** and on the link, right click and select the **"Save As..."** option.\
#
#   - To Upload this file in the **Google Collaboratory** file system. To do this:
#
#     1. Click where the **directory icon** appears on the left side of the window in *Google Collaboratory*
#     2. Move up
#     3. Open  **content**.
#     4. Then click on **⋮** next to  **content**.
#     5. ***Upload*** the **`titanic.csv`** file you previously downloaded and click **"OK"**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Read the the titanic csv file into the the titanic data frame
titanic = pd.read_csv('titanic.csv')

# %%
headers = ['PassengerID','Survived','Pclass','Name','Sex','Age','SibSp','Parch','Ticket','Fare','Cabin','Embarked']

# %%
df = pd.read_csv(titanic, names = headers)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-278-0994a0cd6eaa> in <module>
# ----> 1 df = pd.read_csv(titanic, names = headers)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# ## **1. Types of variables**
#
# ---
# You will need to identify and explore the different types of variables (columns) in the dataset and store the requested answers in the requested variables at each point.
#
# Use the following cells to freely explore the dataset using pandas. Then record your answers to the questions below.
#
# Ej:

# %%
titanic.loc[:,"Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
#TEST_CELL
### Write your code here ### 
titanic.loc[:,"Sex"]
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
#TEST_CELL
### Write your code here ### 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerID  892 non-null    object
#  1   Survived     892 non-null    object
#  2   Pclass       892 non-null    object
#  3   Name         892 non-null    object
#  4   Sex          892 non-null    object
#  5   Age          715 non-null    object
#  6   SibSp        892 non-null    object
#  7   Parch        892 non-null    object
#  8   Ticket       892 non-null    object
#  9   Fare         892 non-null    object
#  10  Cabin        205 non-null    object
#  11  Embarked     890 non-null    object
# dtypes: object(12)
# memory usage: 83.8+ KB

# %%
#TEST_CELL
### Write your code here ### 
df.head()
# Out:
#    PassengerID  Survived  Pclass  \
# 0  PassengerId  Survived  Pclass
# 1            1         0       3
# 2            2         1       1
# 3            3         1       3
# 4            4         1       1
#
#                                                 Name     Sex  Age  SibSp  \
# 0                                               Name     Sex  Age  SibSp
# 1                            Braund, Mr. Owen Harris    male   22      1
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                             Heikkinen, Miss. Laina  female   26      0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
#
#    Parch            Ticket     Fare  Cabin  Embarked
# 0  Parch            Ticket     Fare  Cabin  Embarked
# 1      0         A/5 21171     7.25    NaN         S
# 2      0          PC 17599  71.2833    C85         C
# 3      0  STON/O2. 3101282    7.925    NaN         S
# 4      0            113803     53.1   C123         S

# %%
missing_data = titanic.isnull()
missing_data.head(10)
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
# 3        False     False   False  False  False  False  False  False   False
# 4        False     False   False  False  False  False  False  False   False
# 5        False     False   False  False  False   True  False  False   False
# 6        False     False   False  False  False  False  False  False   False
# 7        False     False   False  False  False  False  False  False   False
# 8        False     False   False  False  False  False  False  False   False
# 9        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin  Embarked
# 0  False   True     False
# 1  False  False     False
# 2  False   True     False
# ...

# %%
for column in missing_data.columns.values.tolist():
  print(column)
  print(missing_data[column].value_counts())
  print('')
# Out:
# PassengerID
# False    892
# Name: PassengerID, dtype: int64
#
# Survived
# False    892
# Name: Survived, dtype: int64
#
# Pclass
# False    892
# Name: Pclass, dtype: int64
#
# Name
# False    892
# Name: Name, dtype: int64
#
# Sex
# False    892
# Name: Sex, dtype: int64
#
# Age
# False    715
# True     177
# Name: Age, dtype: int64
#
# SibSp
# False    892
# Name: SibSp, dtype: int64
#
# Parch
# False    892
# Name: Parch, dtype: int64
#
# Ticket
# False    892
# Name: Ticket, dtype: int64
#
# Fare
# False    892
# Name: Fare, dtype: int64
#
# Cabin
# True     687
# False    205
# Name: Cabin, dtype: int64
#
# Embarked
# False    890
# True       2
# Name: Embarked, dtype: int64

# %% [markdown]
# **Total rows of missing data:**
#
#
# 1.   **Age**: 177
# 2.   **Cabin**: 687
# 3.   **Embarked**: 2

# %% [markdown]
# ### **1.1. Variables with missing values**
# ---
#
# > **Which variables have missing values?**
#
#
# Fill the list **`variables_with_missing_values`** with the correct answer. The order of the names of the variables is not important.
# The answer must be a subset of the names of the variables of the dataset:
#
# **`['PassengerId', 'Survived', 'Pclass',
#        'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare',
#        'Cabin', 'Embarked']`**

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
#
# * In this exercise you can explore manually using functions like **`.describe`** or **`.info`** to identify variables with missing values but you have to use  **`.isnull().any()`** to do it in coding.

# %%
# GRADED VARIABLE: variables_with_missing_values:

### Write your code here ###  (~ 1 line of code)
variables_with_missing_values = titanic.columns[titanic.isnull().any()].tolist()
variables_with_missing_values
# Out:
# ['Age', 'Cabin', 'Embarked']

# %% [markdown]
# ### **1.2. Categorical variables**
# ---
#
# > **Which variables have categorical values?**
#
# Fill the list **`categorical_variables`** with the correct answer.
#
# The order of the names of the variables is not important. The answer must be a subset of the names of the variables of the dataset:
#
# **`['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']`**

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
#
# * In this exercise you can explore manually but you have to use functions like **`.select_dtypes(exclude=["number"]))`** to do it in coding.

# %%
# GRADED VARIABLE: categorical_variables (list):

### Write your code here ###  (~ 1 line of code)
categorical_variables = titanic.select_dtypes(exclude=['number']).columns
categorical_variables
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# ### **1.3. Boarding counts**
# ---
#
# Fill the list embarcaron with the correct answer. The order of the output is not important. The answer must have 3 numerical values corresponding to the number of people who boarded in
#
#
# > **How many passengers boarded in the ports?**
#
# Fill the list **`boarding_counts`** with the correct answer. The order of the output is not important.
#
# The answer must have 3 numerical values corresponding to the number of people who boarded in:
#
# * *Southampton* (S)
# *  *Cherbourg* (C)
# * *Queenstown* (Q)

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
#
# *  In this exercise you can explore manuallybut you have use a *pandas*  function that performs counts of the categorical data stored in a variable.
#
# * Remember that the column **'Embarked'** stores the data about the port of embarkation of the passengers.

# %%
# GRADED VARIABLE: boarding_counts:
#for column in missing_data.columns.values.tolist():
 # print(column)
#  print(missing_data[column].value_counts())
 # print('')
### Write your code here ###  (~ 1 line of code)
boarding_counts = titanic['Embarked'].value_counts()
boarding_counts
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# ## **2.  Survival**
# ---
#
# The dataset *Titanic* has the variable Survived **`Survived`**.  This indicates who survived the tragedy, representing the survivors with a value equal to $1$ and the victims with a value of$0$.
#
# We are interested in knowing which variables most influenced a person's survival.
#
# * For each numerical variable find the mean value of those who survived.
#
# * For the categorical variable **`Sex`**, find the values of the proportion of survivors for women (*female*) and men  (*male*).

# %% [markdown]
# ### **2.1. Survival in numeric variables**
# ---
#
# Find the mean value of all numerical variables for those who survived.
#
# Although it is possible to obtain the result in a single line of code, it is recommended to first calculate the averages of the numerical variables for both groups of passengers: those who survived and those who did not, and then select the averages of those who survived. Therefore, this exercise is divided into two parts.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
#
# * Remember that you can form groups from variables or conditions with the use of the function **`groupby`** and then perform aggregation operations such as the average **`mean`** or the sum **`sum`**.
# * For this exercise you should consider variables with numerical values, even if they are interpreted as categorical variables. Delegate this decision to *pandas* and its functions that only operate on numeric values.

# %% [markdown]
# First, find the averages of the numerical variables for both groups of passengers: survivors and non-survivors.
# > **Note**: Keep in mind that the requested data type is a ***Dataframe*** object called **`averages_by_group`**.

# %%
# GRADED VARIABLE: boarding_counts:

### Write your code here ###  (~ 1 line of code)
averages_by_group = pd.DataFrame(titanic.groupby(['Survived']).mean()) # Replace the empty DataFrame with the correct answer.

# %%
#TEST_CELL
averages_by_group > 10
# Out:
#           PassengerId  Pclass   Age  SibSp  Parch  Fare
# Survived
# 0                True   False  True  False  False  True
# 1                True   False  True  False  False  True

# %% [markdown]
# **Expected output:**
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Pclass</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Fare</th>
#     </tr>
#     <tr>
#       <th>Survived</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>True</td>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>True</td>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now you must select the averages of the group that survived. For example, for those who survived the average age (variable **`Age`**) is approximately **`28.343690`** years.
#
# When interpreting the results you can ignore the variable **`PassengerId`** which, although it is a numeric value, is used as an identifier. Instead, it might be interesting to compare the differences in fares (**`Fare`**) between both groups.
#
# Leave the obtained averages per variable in a *Pandas* *Series* object called **`numeric_survival`**.
#
#
# > **Note:** Keep in mind that the data type being requested is a ***Series*** object.

# %%
# GRADED VARIABLE: numeric_survival:

### Write your code here ###  (~ 1 line of code) 
numeric_survival = pd.Series(averages_by_group.iloc[1]) # Replace the empty Series object with the correct answer.

# %%
#TEST_CELL
numeric_survival.astype(int)
# Out:
# PassengerId    444
# Pclass           1
# Age             28
# SibSp            0
# Parch            0
# Fare            48
# Name: 1, dtype: int64

# %% [markdown]
# **Expected output:**
# ```python
# PassengerId    444
# Pclass           1
# Age             28
# SibSp            0
# Parch            0
# Fare            48
# Name: 1, dtype: int64
# ```

# %% [markdown]
# ### **2.2. Survival in categorical variables**
# ---
#
# Construct a *pandas* ***DataFrame*** object called **`survival_sex`** that contains the average survival in each group from the variable **`Sex`**. You must find the values of the proportions of survivors for women and men separately. For example, if there were $3$ surviving females out of a total of $4$ females, and $2$ surviving males out of a total of $4$ males; the corresponding proportions would be: **`female: 0.75`** and **`male: 0.5`**.
#
# You can use the following cell to find the corresponding values and put them into the ***DataFrame*** **`survival_sex`**.
#
# > **Note:** Keep in mind that the type of data requested is a ***DataFrame***.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
#
# * Remember that you can form groups from variables or conditions with the use of the function **`groupby`** and then perform aggregation operations such as the average **`mean`** or the sum **`sum`* *.
# * The proportion of a variable of binary values ($0$ or $1$) can be obtained from the average, assuming the values in $1$ as the instances that are part of the proportion, and those that are in $0$ those that are not.

# %%
# GRADED VARIABLE: survival_sex:
#averages_by_group = pd.DataFrame(titanic.groupby(['Survived']).mean()) 
### Write your code here ###  (~ 1-2 line of code) 
survival_sex = pd.DataFrame(titanic.groupby(['Sex']).mean()['Survived']) # Reemplace el DataFrame vacío por la respuesta correcta.

# %%
#TEST_CELL
(survival_sex * 100).astype(int)
# Out:
#         Survived
# Sex
# female        74
# male          18

# %% [markdown]
# **Expected output:**
#
# ```python
# 	    Survived
# Sex
# female  74
# male    18
# ```

# %% [markdown]
# ## **3. Elimination of records with missing values**
#
# The *Titanic* dataset has several rows and columns with missing values. An alternative to cleaning the *dataset* is to delete records (rows) that have at least one missing variable or delete variables (columns) that have at least one missing value.
#
# Using *pandas*:
# 1. Save to the *DataFrame* **`non_null_rows_titanic`** the dataset after rows with missing values are removed.
# 2. Store in the *DataFrame* **`non_null_cols_titanic`** the dataset after columns with missing values are removed.
#
# **IMPORTANT**: Be careful not to overwrite or modify the original *Dataframe* **`full_titanic`**. In case you modify it by mistake, you must load it again.

# %% [markdown]
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
#
# * *Pandas* has several functions for dealing with missing values like **`fillna`**, **`dropna`**, **`isna`** and **`notna`**, which allow you to perform different tasks with these types of values.
# * In *pandas*, as in *NumPy*, it is possible to use the **`axis`** argument in various functions. It is very useful when you want to distinguish between rows and columns to perform a certain operation. Verify that the dimension you are performing the operation on is correct.

# %% [markdown]
# ### **3.1. Elimination of rows with missing values**

# %%
# GRADED VARIABLE: non_null_rows_titanic

### Write your code here ###  (~ 1-2 line of code) 
non_null_rows_titanic = pd.DataFrame(titanic.dropna()) # Reemplace el DataFrame vacío por la respuesta correcta.

# %%
#TEST_CELL
non_null_rows_titanic.count()
# Out:
# PassengerId    183
# Survived       183
# Pclass         183
# Name           183
# Sex            183
# Age            183
# SibSp          183
# Parch          183
# Ticket         183
# Fare           183
# Cabin          183
# Embarked       183
# dtype: int64

# %% [markdown]
# **Expected output:**
#
# ```python
# PassengerId    183
# Survived       183
# Pclass         183
# Name           183
# Sex            183
# Age            183
# SibSp          183
# Parch          183
# Ticket         183
# Fare           183
# Cabin          183
# Embarked       183
# dtype: int64
# ```

# %% [markdown]
# ### **3.2. Removing columns with missing values**

# %%
# GRADED VARIABLE: non_null_cols_titanic

### Write your code here ###  (~ 1-2 line of code)  
non_null_cols_titanic = pd.DataFrame(titanic.dropna(axis=1)) # Replace the empty DataFrame with the correct answer.

# %%
#TEST_CELL
non_null_cols_titanic.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# dtype: int64

# %% [markdown]
# **Expected output:**
#
# ```python
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# dtype: int64
# ```

# %% [markdown]
# ## **4. Storage capacity**

# %% [markdown]
# Given the size of the original *dataset* of $891$ rows and $12$ columns, it had an original capacity to store $10692$ data (although some of it was empty). Performing the elimination of variables or records due to wrong format or missing information is a compromise between quantity and quality in the data set.
#
# How many values or cells do the new datasets created with the removal of missing data have?

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
#
# * *Pandas* *DataFrame* objects have properties that reveal interesting features. Many times it is necessary to use these properties. Some of them are: **`index`**, **`dtypes`**, **`ndim`**, **`size`**, **`shape`**, among others.

# %% [markdown]
# ### **4.1. What is the capacity of the DataFrame `**non_null_rows_titanic**`?**

# %% [markdown]
# How can these results be interpreted? Please always remember to analyze and interpret your findings.

# %%
# GRADED VARIABLE: full_rows 

### Write your code here ###  (~ 1 line of code) 
full_rows = titanic.dropna().size
### End of code ###

full_rows
# Out:
# 2196

# %% [markdown]
# ### **4.2. What is the capacity of the `non_null_cols_titanic` DataFrame?**

# %%
# GRADED VARIABLE: full_cols 

### Write your code here ###  (~ 1 line of code) 
full_cols = titanic.dropna(axis=1).size
### End of code ###

full_cols
# Out:
# 8019

# %% [markdown]
# Considering the resulting number of records with each option, either delete columns or delete rows: which would work best for a data analysis task? why?

# %% [markdown]
# **Answer:** If we manage to analyze both Dataframes `non_null_rows_titanic` and `non_null_cols_titanic` we see that the dataframe that has a larger amount of data is `non_null_cols_titanic`, therefore with a larger amount of data we are able to provide a more complete description for a data analysis task.

# %% [markdown]
# ## **5. Imputation of ages**
# ---
# Many times it is not desirable to delete entire columns, even if they contain a few records with missing values, as it can mean losing a lot of other valuable data.
#
# In some cases, when performing data cleaning, you can choose to carry out a [**data imputation**](https://es.wikipedia.org/wiki/Imputaci%C3%B3n_(estad %C3%ADstic)). This consists of replacing missing values with other specific values. For example, the mean for numerical variables, or the most frequent value in the case of categorical variables.
#
# > **IMPORTANT: This type of procedure must be validated with business or domain experts so as not to bias the data in any way, since it implies the creation of artificial data that may not correspond to reality.**

# %% [markdown]
# In the next cell you can create a copy of the original *DataFrame*. This copy will be modified to have the complete answer in the following points.

# %%
### DO NOT MODIFY THIS CELL
# Create copy of titanic
imputed_cols_titanic = titanic.copy()

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
#
# * *Pandas* has several functions for dealing with missing values like **`fillna`**, **`dropna`**, **`isna`** and **`notna`**, which allow you to perform different tasks with these types of values.
# * Check your notes or previous resources for the functions needed to do operations like summation, average, or find the maximum of an object in *pandas*, and apply the ones needed for this exercise.

# %% [markdown]
# Using *pandas* save in **`imputed_cols_titanic`** the *DataFrame* that results after replacing the missing values in the **`Age`** column with the average value of that variable. Be careful not to overwrite the original *DataFrame* **`full_titanic`**.
#
# Although we could do this in a single line of code, we'll do it in $2$ parts:

# %% [markdown]
# ### **5.1. Find the mean of the variable `Age`**

# %%
# GRADED VARIABLE: age_mean

### Write your code here ###  (~ 1 line of code) 
age_mean = titanic['Age'].astype('float').mean()
age_mean
# Out:
# 29.69911764705882

# %% [markdown]
# ### **5.2. Set the missing values in the `Age` column to the middle value**

# %% [markdown]
# Assign missing values in the **`Age`** column to the mean value of that variable in the **`imputed_cols_titanic`** dataframe:

# %%
# GRADED VARIABLE: imputed_cols_titanic['Age']

### Write your code here ###  (~ 1 line of code) 
imputed_cols_titanic['Age'] = imputed_cols_titanic['Age'].fillna(age_mean) # Modify this line

# %%
#TEST_CELL
# Verify that there are no missing values:
imputed_cols_titanic['Age'].isna().sum()
# Out:
# 0

# %% [markdown]
# The output of the above cell should be:
# ```python
# 0
# ```

# %% [markdown]
# ## **6. Creating the `Family`** feature
# ---
# The data set has the variables **`SibSp`** and **`Parch`** for the registration of relatives on board the ship. **`SibSp`** corresponds to the number of crew members who are siblings or spouse of the passenger. For its part, **`Parch`** represents the number of parents (or grandparents) and children (or grandchildren).
#
# To condense this information into a single variable, they can be added to obtain the size of the family of each crew member.
#
# Create a new column called **`Family`** that stores the sum of the **`SibSp`** and **`Parch`** columns. Use and modify the *DataFrame* **`imputed_cols_titanic`**.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
#
# * *Pandas* allows you to use operators such as addition and multiplication between your objects, respecting the rules of *NumPy*.
# * Make sure to use the correct name of the new column and the original columns, and not to modify the original *dataset* to prevent scoring errors.

# %%
# GRADED VARIABLE: imputed_cols_titanic['Family']

### Write your code here ###  (~ 1 line of code) 
imputed_cols_titanic['Family'] = imputed_cols_titanic['SibSp'] + imputed_cols_titanic['Parch']

# %%
#TEST_CELL
imputed_cols_titanic['Family'].head(10)
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    0
# 5    0
# 6    0
# 7    4
# 8    2
# 9    1
# Name: Family, dtype: int64

# %% [markdown]
# The output of the above cell should be:
# ```python
# 0    1
# 1    1
# 2    0
# 3    1
# 4    0
# 5    0
# 6    0
# 7    4
# 8    2
# 9    1
# Name: Family, dtype: int64
# ```

# %%
#TEST_CELL
import numpy as np
print(np.array(imputed_cols_titanic['Family']).sum())
# Out:
# 806

# %% [markdown]
# The output of the above cell should be:
# ```python
# 806
# ```

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
#
# * *matplotlib.pyplot* has several ploting functions like, **`.pie`**, **`.hist`**, etc; which allow you to perform different exploratory graphical analysis.
# * *statsmodels.graphics.mosaicplot* has the **`mosaic`** plot analyze one factore versus another factor.

# %% [markdown]
# **How can all these results be interpreted? Please always remember to analyze and interpret your findings and use plots to support your findings:** ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
died_survived_proportion = titanic['Survived'].value_counts()
mpl.style.use('ggplot') 
labels = ['Died '+str(died_survived_proportion[0]),'Survived '+str(died_survived_proportion[1])]
explode = (0.1,0)
plt.pie(died_survived_proportion, explode = explode, labels = labels, autopct='%1.1f%%', shadow=True)
plt.title('Died Survived proportion')
plt.axis('equal')

plt.show()

# %% [markdown]
# Around ***38%*** of people survived, having a mortality of **61.6%**. This can be explained by the fact that few people were given priority when leaving the Titanic, being the main cause of death drowning and freezing in the cold waters.

# %%
df_agedistribution = titanic['Age']
plt.hist(df_agedistribution, bins = 20, rwidth=.9, alpha=.75, )
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)

# %% [markdown]
# On this histogram we represented the frequency distribution of a few data points for the variable `Age`. We see that most of the people on board of the Titanic were teenagers between 18-28 years old.
#
# >  **NOTE**: This histogram was done with the dataframe that has missing values, ***now let's see the same process but for the modified dataframe:***

# %%
df_modifiedAge = imputed_cols_titanic['Age']
plt.hist(df_modifiedAge, bins = 20, rwidth=.9, alpha=.75, color='green')
plt.title('Age distribution with no missing values')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)

# %% [markdown]
# Here we see a huge difference between the first histogram, where the tendency of Age was people were teenagers, now the tendency is people that were 30 years old. This is why replacing or deleting missing values from a dataframe needs to be done with the supervision of an expert as it can lead to  ***bias*** and can result in decreased ***accuracy***.

# %%
from statsmodels.graphics.mosaicplot import mosaic

# %%
mosaic(titanic.sort_values('Sex'),['Sex','Survived'],)
# Out:
# (<Figure size 432x288 with 3 Axes>,
#  {('female', '1'): (0.0, 0.0, 0.3506597204772992, 0.7395729733161224),
#   ('female', '0'): (0.0,
#    0.7428952324523349,
#    0.3506597204772992,
#    0.2571047675476649),
#   ('male', '1'): (0.3556348448554087,
#    0.0,
#    0.6443651551445913,
#    0.18828054376802913),
#   ('male', '0'): (0.3556348448554087,
#    0.19160280290424175,
#    0.6443651551445913,
#    0.8083971970957582)})

# %% [markdown]
# ##**Analisis:**
# With the graphs we can determine that the population of females survived more than the males, this may be caused due to the fact that females were given priority to leave the Titanic. As for the Embarkation being **Southampton (S)**, **Cherbourg (C)**, and **Queenstown (Q)** we see that the ratio for most people that died were those who embarked in **Southampton(S)**. Most passengers in Pclass=1 survived too, knowing that Pclass varies in terms of the age distribution seen above. Males also had better survival rate in Pclass=3 when comparing them to Cherbourg and Queenstion (C and Q ports respectively).

# %% [markdown]
# **Congratulations!** You have finished the quiz. Good work!

# %% [markdown]
# ## **Credits**
# Created by
#   - German Hernandez
#   - Oscar Fabian Sierra Daza
#
# Modififying quizzes from
#   - Felipe Restrepo Calle
#   - Alberto Nicolai Romero Martínez
#   - Miguel Angel Ortiz Marín
